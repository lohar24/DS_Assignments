# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
from scipy.stats import skew,norm,kurtosis
df=pd.read_csv(r'/content/sales_data_with_discounts.csv')
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
#Identify Categorical columns from .csv file(dataframe)
categorical_columns=df.select_dtypes(include=['object']).columns.tolist()
categorical_columns
# Out:
# ['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model']

# %%
#Bar graph for categorical columns
plt.title('categorical column Date Bar Graph')
df['Date'].value_counts().plot.bar()
# Out:
# <Axes: title={'center': 'categorical column Date Bar Graph'}, xlabel='Date'>

# %%
plt.title('categorical column Day Bar Graph')
df['Day'].value_counts().plot.bar()
# Out:
# <Axes: title={'center': 'categorical column Day Bar Graph'}, xlabel='Day'>

# %% [markdown]
# **Insight**:
# sales from friday to wednesday are relatively uniform however those are higher on Thursaday

# %%
plt.title('categorical column SKU Bar Graph')
df['SKU'].value_counts().plot.bar()
# Out:
# <Axes: title={'center': 'categorical column SKU Bar Graph'}, xlabel='SKU'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
plt.title('categorical column City Bar Graph')
df['City'].value_counts().plot.bar()
# Out:
# <Axes: title={'center': 'categorical column City Bar Graph'}, xlabel='City'>

# %%
plt.title('categorical column BU Bar Graph')
df['BU'].value_counts().plot.bar()
# Out:
# <Axes: title={'center': 'categorical column BU Bar Graph'}, xlabel='BU'>

# %% [markdown]
# **Insight**: Sales are relatively uniform for different Business Units

# %%
plt.title('categorical column Brand Bar Graph')
df['Brand'].value_counts().plot.bar()
# Out:
# <Axes: title={'center': 'categorical column Brand Bar Graph'}, xlabel='Brand'>

# %% [markdown]
# **Insight**: There is fluctutaion in saled for different brands Jeera brand is higly sold comparitively.

# %%
plt.title('categorical column Model Bar Graph')
df['Model'].value_counts().plot.bar()
# Out:
# <Axes: title={'center': 'categorical column Model Bar Graph'}, xlabel='Model'>

# %% [markdown]
# **Insight**: Sales are uniform for different Models.
#
# **Conclusion**: By analyzing the bar chart depicting above sales data, we can identify key insights into consumer preferences, seasonal trends, and growth opportunities within different market segments. These insights enable strategic decision-making such as resource allocation, inventory management, and marketing strategies tailored to maximize sales and profitability across various categories.
